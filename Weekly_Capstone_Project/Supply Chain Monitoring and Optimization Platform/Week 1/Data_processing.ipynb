# %%
import pandas as pd

# %%
df = pd.read_csv('orders.csv')
print(df)
# Out:
#     order_id  supplier_id  product_id  quantity  order_date delivery_date
# 0          1          1.0           2      50.0  2025-06-01    2025-06-06
# 1          2          2.0           5      30.0  2025-06-05    06/08/2025
# 2          3          3.0           1     100.0  2025-06-07    2025-06-17
# 3          4          4.0           6      20.0  2025-06-10           NaN
# 4          5          5.0           3      75.0  06/11/2025    2025-06-15
# 5          6          1.0           7      15.0  2025-06-12    2025-06-17
# 6          7          2.0           4     200.0  2025-06-13    2025-06-16
# 7          8          NaN           5      40.0  2025-06-14    2025-06-19
# 8          9          3.0           2      60.0  2025-06-15    2025/06/20
# 9         10          4.0           1      90.0  2025-06-16           NaN
# 10        11          5.0           6      25.0  2025-06-17    2025-06-22
# 11        12          1.0           3       NaN  2025-06-18    2025-06-23
# ...

# %%
print("Shape of dataset (rows, columns):", df.shape)
# Out:
# Shape of dataset (rows, columns): (15, 6)

# %%
print("\nColumn names:", df.columns.tolist())
# Out:
# Column names: ['order_id', 'supplier_id', 'product_id', 'quantity', 'order_date', 'delivery_date']

# %%
print("\n--- Dataset Info ---")
df.info()
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       15 non-null     int64
#  1   supplier_id    13 non-null     float64
#  2   product_id     15 non-null     int64
#  3   quantity       14 non-null     float64
#  4   order_date     15 non-null     object
#  5   delivery_date  13 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 852.0+ bytes

# %%
print("\n--- First 5 Rows ---")
print(df.head())
# Out:
# --- First 5 Rows ---
#    order_id  supplier_id  product_id  quantity  order_date delivery_date
# 0         1          1.0           2      50.0  2025-06-01    2025-06-06
# 1         2          2.0           5      30.0  2025-06-05    06/08/2025
# 2         3          3.0           1     100.0  2025-06-07    2025-06-17
# 3         4          4.0           6      20.0  2025-06-10           NaN
# 4         5          5.0           3      75.0  06/11/2025    2025-06-15

# %%
print("\n--- Missing Values Per Column ---")
print(df.isnull().sum())
# Out:
# --- Missing Values Per Column ---
# order_id         0
# supplier_id      2
# product_id       0
# quantity         1
# order_date       0
# delivery_date    2
# dtype: int64

# %%
print("\n--- Duplicate Rows ---")
print("Duplicate count:", df.duplicated().sum())
# Out:
# --- Duplicate Rows ---
# Duplicate count: 0

# %%
print("\n--- Summary Statistics ---")
print(df.describe())
# Out:
# --- Summary Statistics ---
#         order_id  supplier_id  product_id    quantity
# count  15.000000    13.000000   15.000000   14.000000
# mean    8.000000     2.769231    3.800000   62.500000
# std     4.472136     1.423250    2.144761   47.666711
# min     1.000000     1.000000    1.000000   15.000000
# 25%     4.500000     2.000000    2.000000   31.250000
# 50%     8.000000     3.000000    4.000000   52.500000
# 75%    11.500000     4.000000    5.500000   78.750000
# max    15.000000     5.000000    7.000000  200.000000

# %%
import numpy as np

# %%
print("Rows before dropping missing supplier_id:", len(df))
df = df.dropna(subset=['supplier_id'])
print("Rows after dropping missing supplier_id:", len(df))
# Out:
# Rows before dropping missing supplier_id: 15
# Rows after dropping missing supplier_id: 13

# %%
median_qty = df['quantity'].median()
df['quantity'] = df['quantity'].fillna(median_qty)
print(f"\nFilled missing quantity with median: {median_qty}")
# Out:
# Filled missing quantity with median: 52.5

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed')

# %%
df['delivery_date'] = pd.to_datetime(df['delivery_date'], format='mixed')

# %%
df['supplier_id'] = df['supplier_id'].astype(int)
df['quantity'] = df['quantity'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       13 non-null     int64
#  1   supplier_id    13 non-null     int64
#  2   product_id     13 non-null     int64
#  3   quantity       13 non-null     int64
#  4   order_date     13 non-null     datetime64[ns]
#  5   delivery_date  11 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(4)
# memory usage: 728.0 bytes

# %%
print("\n--- Missing Values After Cleaning ---")
print(df.isnull().sum())
# Out:
# --- Missing Values After Cleaning ---
# order_id         0
# supplier_id      0
# product_id       0
# quantity         0
# order_date       0
# delivery_date    2
# dtype: int64

# %%
print("\n--- Cleaned Data Preview ---")
print(df)
# Out:
# --- Cleaned Data Preview ---
#     order_id  supplier_id  product_id  quantity order_date delivery_date
# 0          1            1           2        50 2025-06-01    2025-06-06
# 1          2            2           5        30 2025-06-05    2025-06-08
# 2          3            3           1       100 2025-06-07    2025-06-17
# 3          4            4           6        20 2025-06-10           NaT
# 4          5            5           3        75 2025-06-11    2025-06-15
# 5          6            1           7        15 2025-06-12    2025-06-17
# 6          7            2           4       200 2025-06-13    2025-06-16
# 8          9            3           2        60 2025-06-15    2025-06-20
# 9         10            4           1        90 2025-06-16           NaT
# 10        11            5           6        25 2025-06-17    2025-06-22
# 11        12            1           3        52 2025-06-18    2025-06-23
# ...
