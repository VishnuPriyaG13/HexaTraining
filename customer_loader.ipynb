# %%
customer_data = [
    (101, "John", "Chennai"),
    (102, "Alice", "Coimbatore"),
    (103, "Bob", "Chennai"),
    (104, "Emma", "Madurai"),
    (105, "David", "Coimbatore")
]

# %%
columns = ["customer_id", "name", "city"]

customer_df = spark.createDataFrame(customer_data, columns)

# %%
display(customer_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th>city</th></tr></thead><tbody><tr><td>101</td><td>John</td><td>Chennai</td></tr><tr><td>102</td><td>Alice</td><td>Coimbatore</td></tr><tr><td>103</td><td>Bob</td><td>Chennai</td></tr><tr><td>104</td><td>Emma</td><td>Madurai</td></tr><tr><td>105</td><td>David</td><td>Coimbatore</td></tr></tbody></table></div>

# %%
customer_df.write.mode("overwrite").saveAsTable("customer_table")
